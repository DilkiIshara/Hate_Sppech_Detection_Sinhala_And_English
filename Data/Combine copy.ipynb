# %%
import pandas as pd

# Load datasets
si_2 = pd.read_csv("SOLD_test.csv")  # columns: text, label ("OFF"/"NOT")



# ---------- Sinhala (SOLD dataset) ----------
sold_map = {"OFF": 1, "NOT": 0}
si2_std = si_2[["text", "label"]].copy()
si2_std["label_num"] = si2_std["label"].map(sold_map)
si2_std["lang"] = "si"
si2_std = si2_std.drop(columns=["label"])

# ---------- Combine all datasets ----------
merged = pd.concat(
    [
        si2_std[["text", "label_num", "lang"]],
    ],
    ignore_index=True
).rename(columns={"label_num": "label"}) \
 .dropna(subset=["text", "label"])

# Save merged dataset
merged.to_csv("sold_test_normalized.csv", index=False)

print("Final merged dataset created")
print(merged.head())
print(merged["lang"].value_counts())
print(merged["label"].value_counts())
# Out:
# Final merged dataset created
#                                                 text  label lang
# 0                  තේ නෙවෙයි තෝ බීලා ඉන්නෙ ගිනි වතුර      0   si
# 1  @USER තුනක් ඕනේ නෑ එකක් ගැහුවනම් ඇති ලංකාවට ආප...      0   si
# 2  @USER ,  @USER  @USER ටහුඩු ඒකි තනියම ජීවත් වෙ...      0   si
# 3           @USER මර්විනුත් මුද්දරයක් වෙයිද දන්නේ නැ      0   si
# 4  @USER ගොසිප් පීපල් නෙමේ හුත්තො. තෝ වගේ හොරෙක්ට...      1   si
# lang
# si    2500
# Name: count, dtype: int64
# label
# 0    1485
# 1    1015
# Name: count, dtype: int64
